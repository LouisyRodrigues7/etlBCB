# %% [markdown]
# ## Estatísticas de Meios de Pagamentos
#
# Este conjunto contém diversas estatísticas relacionadas aos seguintes MEIOS DE PAGAMENTO:
#
# Instrumentos de periodicidade mensal, com atualização 17 dias após o final do mês de referência:
#
# Pix (fonte: SPI e documento 1201)
# TED (fonte: CIP-SITRAF e STR)
# Boletos (fonte: CIP-SILOC)
# DOC e TEC (fonte: CIP-SILOC)
# Cheque (fonte: Compe)
# Instrumentos de periodicidade trimestral, com atualização 2 meses após o final do trimestre de referência:
#
# Cartões de crédito, débito e pré-pagos (fonte: documentos 6308 e 6334)
# Pagamentos de convênio, saques, transferências intrabancárias e débito direto (fonte: documento 6209)
# Volumetria das transações intrabancárias (fonte: documento 6209)
# Estabelecimentos credenciados (fonte: documento 6334)
# Volumetria por canal de acesso e produto (fonte: documento 6209)
# Quantidade de ATMs (fonte: documento 6209)
# Tarifas de intercâmbio (TIC) e taxas de desconto (MDR) - (fonte: documento 6334)
# Terminais POS/PDV
# Programas de recompensa e fidelidade
#
# Dicionário de dados
#
# | Nome                         | Tipo    | Título                                    | Descrição                                                                                                                                                                                                                                       |
# | ---------------------------- | ------- | ----------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | datatrimestre                | texto   | Trimestre                                 |                                                                                                                                                                                                                                                 |
# | valorPix                     | decimal | Valor Pix                                 | Volume financeiro (R\$ milhões) de transações Pix liquidadas trimestralmente no SPI e fora do SPI, considerando ordens de pagamento e devoluções no período. Dados referentes às transações liquidadas fora do SPI estão sujeitas a alterações. |
# | valorTED                     | decimal | Valor TED                                 | Montante financeiro (R\$ milhões) trimestral transferido por meio de TED. Transferência Eletrônica Direta (TED) em tempo real entre diferentes instituições, usada para transferir valores entre correntistas e entre instituições.             |
# | valorTEC                     | decimal | Valor TEC                                 | Montante financeiro (R\$ milhões) trimestral transferido por meio de TEC. Transferência Especial de Crédito (TEC) utilizada por empresas para pagamento de benefícios aos empregados.                                                           |
# | valorCheque                  | decimal | Valor Cheque                              | Montante financeiro (R\$ milhões) de cheques interbancários e intrabancários compensados trimestralmente.                                                                                                                                       |
# | valorBoleto                  | decimal | Valor Boleto                              | Montante financeiro (R\$ milhões) de boletos interbancários e intrabancários compensados trimestralmente.                                                                                                                                       |
# | valorDOC                     | decimal | Valor DOC                                 | Montante financeiro (R\$ milhões) trimestral transferido por meio de DOC.                                                                                                                                                                       |
# | valorCartaoCredito           | decimal | Valor Cartão de Crédito                   | Valor (R\$ milhões) de transações realizadas com cartão de crédito.                                                                                                                                                                             |
# | valorCartaoDebito            | decimal | Valor Cartão de Débito                    | Valor (R\$ milhões) de transações realizadas com cartão de débito trimestralmente.                                                                                                                                                              |
# | valorCartaoPrePago           | decimal | Valor Cartão Pré-pago                     | Valor (R\$ milhões) de transações realizadas com cartão pré-pago trimestralmente.                                                                                                                                                               |
# | valorTransIntrabancaria      | decimal | Valor Transferência Intrabancária         | Montante financeiro (R\$ milhões) de transferências realizadas trimestralmente entre contas de clientes da Instituição, inclusive aplicações e resgates em fundos de investimento.                                                              |
# | valorConvenios               | decimal | Valor Convênio                            | Montante financeiro (R\$ milhões) de arrecadações trimestrais governamentais (tributos e encargos sociais) e não-governamentais, em virtude de convênios firmados entre a instituição e entidades públicas ou privadas.                         |
# | valorDebitoDireto            | decimal | Valor Débito Direto                       | Montante financeiro (R\$ milhões) trimestral de débitos previamente autorizados pelo cliente, referente a contas recorrentes e tarifas de serviços.                                                                                             |
# | valorSaques                  | decimal | Valor Saque                               | Montante sacado (R\$ milhões) nos caixas eletrônicos trimestralmente.                                                                                                                                                                           |
# | quantidadePix                | decimal | Quantidade Pix                            | Quantidade (em milhares) de transações Pix liquidadas trimestralmente no SPI e fora do SPI, considerando ordens de pagamento e devoluções.                                                                                                      |
# | quantidadeTED                | decimal | Quantidade TED                            | Quantidade (em milhares) de TED realizadas trimestralmente.                                                                                                                                                                                     |
# | quantidadeTEC                | decimal | Quantidade TEC                            | Quantidade (em milhares) de TEC realizadas trimestralmente.                                                                                                                                                                                     |
# | quantidadeCheque             | decimal | Quantidade Cheque                         | Quantidade (em milhares) de cheques interbancários e intrabancários compensados trimestralmente.                                                                                                                                                |
# | quantidadeBoleto             | decimal | Quantidade Boleto                         | Quantidade (em milhares) de boletos interbancários e intrabancários compensados trimestralmente.                                                                                                                                                |
# | quantidadeDOC                | decimal | Quantidade DOC                            | Quantidade (em milhares) de DOC realizados trimestralmente.                                                                                                                                                                                     |
# | quantidadeCartaoCredito      | decimal | Quantidade Cartão de Crédito              | Quantidade (em milhares) de transações realizadas com cartão de crédito trimestralmente.                                                                                                                                                        |
# | quantidadeCartaoDebito       | decimal | Quantidade Cartão de Débito               | Quantidade (em milhares) de transações realizadas com cartão de débito trimestralmente.                                                                                                                                                         |
# | quantidadeCartaoPrePago      | decimal | Quantidade Cartão Pré-pago                | Quantidade (em milhares) de transações realizadas com cartão pré-pago trimestralmente.                                                                                                                                                          |
# | quantidadeTransIntrabancaria | decimal | Quantidade de Transferência Intrabancária | Quantidade (em milhares) de transferências realizadas trimestralmente entre contas de clientes da Instituição, inclusive aplicações e resgates em fundos de investimento.                                                                       |
# | quantidadeConvenios          | decimal | Quantidade Convênio                       | Quantidade (em milhares) de arrecadações trimestrais governamentais e não-governamentais referentes a convênios firmados entre a instituição e entidades públicas ou privadas.                                                                  |
# | quantidadeDebitoDireto       | decimal | Quantidade Débito Direto                  | Quantidade (em milhares) de transações trimestrais de débitos previamente autorizados pelo cliente, referentes a contas recorrentes e tarifas de serviços.                                                                                      |
# | quantidadeSaques             | decimal | Quantidade de Saque                       | Quantidade (em milhares) de saques realizados nos caixas eletrônicos trimestralmente.                                                                                                                                                           |

# %% [markdown]
# ## Análise exploratória

# %%
import pandas as pd
import sqlite3

con = sqlite3.connect("src/datasets/etlbcb.db")
query = "select * from meios_pagamentos_tri"
df = pd.read_sql(query, con)
con.close()

# %%
df
# Out:
#           datatrimestre    valorPix     valorTED  valorTEC  valorCheque  \
# 0   2024-12-31 00:00:00  7714115.37  11647265.67      0.00    187486.45
# 23                 58847.58                     307650.07
#
#     quantidadeConvenios  quantidadeDebitoDireto  quantidadeSaques
# 0             633961.05              3795103.04         658974.39
# 1             661918.39              3832577.08         664226.23
# 2             679418.05              3320590.50         698603.67
# 3             716794.83              3238699.12         683043.00
# 4             669806.38              3102557.70         752440.67
# 5             705507.61              2790819.99         758691.59
# 6             734712.47              2556236.88         778454.00
# 7             764472.57              2437253.99         662875.26
# 8             735105.83              1935347.65         742553.43
# 9             766676.25              1965308.38         725040.40
# 10            773505.49              2017609.09         876660.30
# 11            786600.78              2049566.58         838690.74
# 12            755053.35              1809992.06         919580.38
# 13            774410.72              1765464.80         918141.51
# 14            733937.43              1709009.85         924449.90
# 15            766141.92              1704253.83         926234.05
# 16            750242.75              1700531.57        1084574.42
# 17            776086.02              1623252.19        1009737.66
# 18            752351.43              1542581.41         934644.94
# 19            860763.75              1522644.97        1034924.99
# 20            786763.01              1459193.74        1237366.49
# 21            864138.87              1514404.88        1150223.87
# 22            811802.76              1418749.18        1114642.78
# 23            913784.42              1381466.73        1103906.31
#
# [24 rows x 27 columns]

# %% [markdown]
# Primeiro vamos explorar a estrutura do conjunto de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   datatrimestre                 24 non-null     object
#  1   valorPix                      24 non-null     float64
#  2   valorTED                      24 non-null     float64
#  3   valorTEC                      24 non-null     float64
#  4   valorCheque                   24 non-null     float64
#  5   valorBoleto                   24 non-null     float64
#  6   valorDOC                      24 non-null     float64
#  7   valorCartaoCredito            24 non-null     float64
#  8   valorCartaoDebito             24 non-null     float64
#  9   valorCartaoPrePago            24 non-null     float64
#  10  valorTransIntrabancaria       24 non-null     float64
#  11  valorConvenios                24 non-null     float64
#  12  valorDebitoDireto             24 non-null     float64
#  13  valorSaques                   24 non-null     float64
#  14  quantidadePix                 24 non-null     float64
#  15  quantidadeTED                 24 non-null     float64
#  16  quantidadeTEC                 24 non-null     float64
#  17  quantidadeCheque              24 non-null     float64
#  18  quantidadeBoleto              24 non-null     float64
#  19  quantidadeDOC                 24 non-null     float64
#  20  quantidadeCartaoCredito       24 non-null     float64
#  21  quantidadeCartaoDebito        24 non-null     float64
#  22  quantidadeCartaoPrePago       24 non-null     float64
#  23  quantidadeTransIntrabancaria  24 non-null     float64
#  24  quantidadeConvenios           24 non-null     float64
#  25  quantidadeDebitoDireto        24 non-null     float64
#  26  quantidadeSaques              24 non-null     float64
# dtypes: float64(26), object(1)
# memory usage: 5.2+ KB

# %% [markdown]
# Aparentemente não temos dados faltantes, mas vamos comprovar:

# %%
df.isnull().sum()
# Out:
# datatrimestre                   0
# valorPix                        0
# valorTED                        0
# valorTEC                        0
# valorCheque                     0
# valorBoleto                     0
# valorDOC                        0
# valorCartaoCredito              0
# valorCartaoDebito               0
# valorCartaoPrePago              0
# valorTransIntrabancaria         0
# valorConvenios                  0
# valorDebitoDireto               0
# valorSaques                     0
# quantidadePix                   0
# quantidadeTED                   0
# quantidadeTEC                   0
# quantidadeCheque                0
# quantidadeBoleto                0
# quantidadeDOC                   0
# quantidadeCartaoCredito         0
# quantidadeCartaoDebito          0
# quantidadeCartaoPrePago         0
# quantidadeTransIntrabancaria    0
# quantidadeConvenios             0
# quantidadeDebitoDireto          0
# quantidadeSaques                0
# dtype: int64

# %% [markdown]
# Note que data trimestre está como object(string), mas seria mais interessante estar como Date. Vamos comprovar isso.

# %%
type(df['datatrimestre'][0])
# Out:
# str

# %%
df['datatrimestre']
# Out:
# 0     2024-12-31 00:00:00
# 1     2024-09-30 00:00:00
# 2     2024-06-30 00:00:00
# 3     2024-03-31 00:00:00
# 4     2023-12-31 00:00:00
# 5     2023-09-30 00:00:00
# 6     2023-06-30 00:00:00
# 7     2023-03-31 00:00:00
# 8     2022-12-31 00:00:00
# 9     2022-09-30 00:00:00
# 10    2022-06-30 00:00:00
# 11    2022-03-31 00:00:00
# 12    2021-12-31 00:00:00
# 13    2021-09-30 00:00:00
# 14    2021-06-30 00:00:00
# 15    2021-03-31 00:00:00
# 16    2020-12-31 00:00:00
# 17    2020-09-30 00:00:00
# 18    2020-06-30 00:00:00
# 19    2020-03-31 00:00:00
# 20    2019-12-31 00:00:00
# 21    2019-09-30 00:00:00
# 22    2019-06-30 00:00:00
# 23    2019-03-31 00:00:00
# Name: datatrimestre, dtype: object

# %%
df['datatrimestre'][0]
# Out:
# '2024-12-31 00:00:00'

# %% [markdown]
# Convertendo para date.

# %%
df['datatrimestre'] = pd.to_datetime (df['datatrimestre'])
df['datatrimestre'] = df['datatrimestre'].dt.date

# %%
df['datatrimestre'][0]
# Out:
# datetime.date(2024, 12, 31)

# %%
#confirmando que é uma date
type(df['datatrimestre'][0])
# Out:
# datetime.date

# %%
df
# Out:
#    datatrimestre    valorPix     valorTED  valorTEC  valorCheque  valorBoleto  \
# 0     2024-12-31  7714115.37  11647265.67      0.00    187486.45   2530070.72
# 1     2024-09-30  6975429.47  11180217.68      0.00    194330.60   2445000.04
# 2     2024-06-30  6284296.05  10662555.73      0.00    221553.82   2360423.79
# 3     2024-03-31  5429305.43   9651625.56    925.26    190457.25   2248972.68
# 4     2023-12-31  5300155.00  10090921.81   5787.89    221424.78   2317765.95
# 5     2023-09-30  4469529.57   9960251.89   4156.38    218121.88   2296686.99
# 6     2023-06-30  3900377.43  10657463.13   4770.74    228408.82   2249059.61
# 7     2023-03-31  3447198.28   9919602.84   4535.17    240686.19   2211522.99
# 8     2022-12-31  3342913.94  10382121.63   5609.53    242259.61   2259674.53
# 9     2022-09-30  2936413.95  10437763.16   3735.46    267090.22   2248416.63
# 10    2022-06-30  2543384.40  10449574.67   4786.14    271008.09   2210099.22
# 11    2022-03-31  2067826.55   9507158.34   3865.81    255455.43   2032317.14
# 12    2021-12-31  1916418.68   9807293.11   5436.19    264298.16   2072053.93
# 13    2021-09-30  1556916.22   9257046.28   3684.13    271120.34   2001074.00
# 14    2021-06-30  1105735.20   8566787.27   3894.81    264944.31   1839452.36
# 15    2021-03-31   625046.52   7894414.16   4352.44    253527.92   1769759.68
# 15       31687.35               2584404.06              3005004.65
# 16       58634.44               2672666.45              3483509.40
# 17       74377.91               2280096.07              2957015.55
# 18       73763.72               1907929.12              2259584.47
# 19       43503.55               2492783.10              2757914.17
# 20       51756.51               2681083.06              3102432.97
# 21       53387.74               2516328.04              2749305.82
# 22       47739.37               2324477.29              2524775.40
# 23       52449.83               2081348.82              2471245.21
#
#     quantidadeCartaoPrePago  quantidadeTransIntrabancaria  \
# 0                3339927.19                     492218.65
# 1                3132433.07                     426403.58
# 2                3046233.97                     328551.70
# 3                2774237.04                     277240.15
# 4                2974411.01                     376307.77
# 5                2677826.63                     318577.87
# 6                2426618.73                     278256.94
# 7                2237800.76                     256276.86
# 8                2303423.64                     288090.04
# 9                1993806.85                     274847.98
# 10               1750865.66                     269502.24
# 11               1507246.16                     278556.41
# 12               1430826.74                     226318.22
# 13               1603852.67                     244008.40
# 14               1264916.88                     260756.78
# 15               1016901.48                     274419.70
# 16               1056946.56                     348828.24
# 17                795301.85                     338018.29
# 18                533545.65                     303062.51
# 19                577500.51                     293996.77
# 20                159510.21                     365515.57
# 21                109323.89                     347495.65
# 22                 77904.49                     331095.31
# 23                 58847.58                     307650.07
#
#     quantidadeConvenios  quantidadeDebitoDireto  quantidadeSaques
# 0             633961.05              3795103.04         658974.39
# 1             661918.39              3832577.08         664226.23
# 2             679418.05              3320590.50         698603.67
# 3             716794.83              3238699.12         683043.00
# 4             669806.38              3102557.70         752440.67
# 5             705507.61              2790819.99         758691.59
# 6             734712.47              2556236.88         778454.00
# 7             764472.57              2437253.99         662875.26
# 8             735105.83              1935347.65         742553.43
# 9             766676.25              1965308.38         725040.40
# 10            773505.49              2017609.09         876660.30
# 11            786600.78              2049566.58         838690.74
# 12            755053.35              1809992.06         919580.38
# 13            774410.72              1765464.80         918141.51
# 14            733937.43              1709009.85         924449.90
# 15            766141.92              1704253.83         926234.05
# 16            750242.75              1700531.57        1084574.42
# 17            776086.02              1623252.19        1009737.66
# 18            752351.43              1542581.41         934644.94
# 19            860763.75              1522644.97        1034924.99
# 20            786763.01              1459193.74        1237366.49
# 21            864138.87              1514404.88        1150223.87
# 22            811802.76              1418749.18        1114642.78
# 23            913784.42              1381466.73        1103906.31
#
# [24 rows x 27 columns]

# %%
thousands_cols = [
    'quantidadePix', 'quantidadeTED', 'quantidadeTEC', 'quantidadeCheque',
    'quantidadeBoleto', 'quantidadeDOC', 'quantidadeCartaoCredito',
    'quantidadeCartaoDebito', 'quantidadeCartaoPrePago',
    'quantidadeTransIntrabancaria', 'quantidadeConvenios',
    'quantidadeDebitoDireto', 'quantidadeSaques'
]

for col in thousands_cols : 
    df[col] = df[col].round(0) *1_00
    df[col] = df[col] . round(2)

# %% [markdown]
# ## Estatísticas Descritivas
#
# Nosso conjunto de dados está com muitas colunas, vamos nos concentrar em um tema específico para continuar com a análise.
#
# Vamos nos concentrar nas séries de Pix e cartões.

# %%
date_col = ['datatrimestre']

pix_cols = ['valorPix', 'quantidadePix']

card_cols = [
    'valorCartaoCredito', 'quantidadeCartaoCredito',
    'valorCartaoDebito',  'quantidadeCartaoDebito',
    'valorCartaoPrePago', 'quantidadeCartaoPrePago'
]

selected_cols = date_col+pix_cols+card_cols 
df_pix_cards = df[selected_cols].copy()

# %%
df_pix_cards.describe()
# Out:
#            valorPix  quantidadePix  valorCartaoCredito  \
# count  2.400000e+01   2.400000e+01        2.400000e+01
# mean   2.490207e+12   5.781591e+08        4.448634e+11
# std    2.482513e+12   6.045886e+08        1.568315e+11
# min    0.000000e+00   0.000000e+00        2.243895e+11
# 25%    0.000000e+00   0.000000e+00        2.969604e+11
# 50%    1.992123e+12   4.043155e+08        4.606018e+11
# 75%    4.042665e+12   9.826671e+08        5.669088e+11
# max    7.714115e+12   1.796084e+09        7.286220e+11
#
#        quantidadeCartaoCredito  valorCartaoDebito  quantidadeCartaoDebito  \
# count             2.400000e+01       2.400000e+01            2.400000e+01
# mean              3.566431e+08       2.216744e+11            3.482304e+08
# std               1.080436e+08       3.707392e+10            6.185536e+07
# min               1.907929e+08       1.517647e+11            2.259584e+08
# 25%               2.567385e+08       2.019829e+11            2.993008e+08
# 50%               3.710315e+08       2.361434e+11            3.684254e+08
# 75%               4.472067e+08       2.441156e+11            3.967864e+08
# max               5.351538e+08       2.641206e+11            4.282401e+08
#
#        valorCartaoPrePago  quantidadeCartaoPrePago
# count        2.400000e+01             2.400000e+01
# mean         4.204402e+10             1.618759e+08
# std          2.828923e+10             1.068420e+08
# min          5.019160e+09             5.884800e+06
# 25%          1.334950e+10             7.408518e+07
# 50%          4.298120e+10             1.555550e+08
# 75%          6.694979e+10             2.489421e+08
# max          8.563790e+10             3.339927e+08

# %%
selected_cols
# Out:
# ['datatrimestre',
#  'valorPix',
#  'quantidadePix',
#  'valorCartaoCredito',
#  'quantidadeCartaoCredito',
#  'valorCartaoDebito',
#  'quantidadeCartaoDebito',
#  'valorCartaoPrePago',
#  'quantidadeCartaoPrePago']

# %%
df[selected_cols]
# Out:
#    datatrimestre      valorPix  quantidadePix  valorCartaoCredito  \
# 0     2024-12-31  7.714115e+12   1.796084e+09        7.286220e+11
# 1     2024-09-30  6.975429e+12   1.654643e+09        6.632884e+11
# 2     2024-06-30  6.284296e+12   1.535689e+09        6.318115e+11
# 3     2024-03-31  5.429305e+12   1.357546e+09        6.074710e+11
# 4     2023-12-31  5.300155e+12   1.304567e+09        6.301913e+11
# 5     2023-09-30  4.469530e+12   1.111695e+09        5.819024e+11
# 6     2023-06-30  3.900377e+12   9.396579e+08        5.619109e+11
# 7     2023-03-31  3.447198e+12   8.116396e+08        5.355204e+11
# 8     2022-12-31  3.342914e+12   7.807166e+08        5.607654e+11
# 9     2022-09-30  2.936414e+12   6.528602e+08        5.219423e+11
# 10    2022-06-30  2.543384e+12   5.447448e+08        5.015147e+11
# 11    2022-03-31  2.067827e+12   4.250024e+08        4.532924e+11
# 12    2021-12-31  1.916419e+12   3.836286e+08        4.679112e+11
# 13    2021-09-30  1.556916e+12   2.863337e+08        3.990541e+11
soma2 = df_pix_cards['quantidadePix'].sum()

soma1/soma2
# Out:
# np.float64(4307.130297368699)

# %% [markdown]
# Por outro lado:

# %%
(df_pix_cards ['valorPix']/df_pix_cards['quantidadePix']).mean()
# Out:
# np.float64(4911.381725194752)

# %% [markdown]
# A diferença existe porque, na segunda abordagem, você está dando peso igual a cada trimestre, independentemente de quantas transações ocorreram naquele período. Já na primeira, cada transação — seja no trimestre que for — “conta” igualmente, o que faz o trimestre com mais transações influenciar mais o resultado final.
#
#
# | Métrica                                  | Fórmula                                                    | Interpretação                                                  |
# | ---------------------------------------- | ---------------------------------------------------------- | -------------------------------------------------------------- |
# | Média geral (ponderada)                  | $\sum_i valorPix_i \,/\, \sum_i quantidadePix_i$           | Valor médio por transação considerando todo o volume           |
# | Média das médias trimestrais (não-pond.) | $\tfrac{1}{n}\sum_i\bigl(valorPix_i/quantidadePix_i\bigr)$ | Valor médio por transação onde cada trimestre tem “peso” igual |
#
# Use a **média geral** quando quiser o valor médio de toda a amostra, e a **média das médias trimestrais** quando quiser tratar cada período (trimestre) com igual importância.

# %% [markdown]
# ### Variância e Desvio-Padrão

# %%
x = df_pix_cards ['valorPix'] / df_pix_cards['quantidadePix']
print("Média: ", x.mean())
print("Variância: ", x.var(ddof=0))
print("Desvio-padrão: ", x.std(ddof=0))
# Out:
# Média:  4911.381725194752
# Variância:  1481973.2447320726
# Desvio-padrão:  1217.3632345081203

# %% [markdown]
# Esse é o “tamanho típico” da variação em torno de R\$ 491. Na prática, significa que cerca de 68% dos trimestres tiveram valor médio por transação entre
#
#   $$
#     491 - 121{,}7 \approx 369 \quad\text{e}\quad 491 + 121{,}7 \approx 613.
#   $$
#
# ### Interpretação prática
#
# 1. **Dispersão moderada**
#    Um desvio-padrão de R\$ 122 em torno de R\$ 491 equivale a um coeficiente de variação de
#
#    $$
#      \frac{121{,}7}{491} \approx 0{,}25\quad(\,25\%\,),
#    $$
#
#    ou seja, as médias trimestrais flutuam em torno de ±25% da média geral.
#
# 2. **Potenciais causas**
#
#    * **Sazonalidade**: se alguns trimestres (ex.: fim de ano) tendem a ter transações maiores, isso eleva o desvio.
#    * **Mudanças estruturais**: adoção crescente de Pix, promoções ou campanhas podem alterar o ticket médio.
#
# 3. **Uso da métrica**
#
#    * **Planejamento**: saber que “normalmente” o ticket médio fica entre R\$ 369 e R\$ 613 ajuda a projetar receitas futuras.
#    * **Detecção de anomalias**: trimestres fora desse intervalo (muito acima ou abaixo) podem merecer investigação.
#
# Em suma, embora o valor médio seja R\$ 491, existe uma variabilidade não desprezível de cerca de R\$ 122 entre trimestres, indicando que fatores sazonais ou de comportamento do consumidor fazem o ticket médio de Pix oscilar em torno desse patamar.

# %% [markdown]
# ## Visualizações
#
# para complementar o processo de análise de dados vamos gerar alguns gráficos, para isso usaremos a biblioteca matplotlib.

# %% [markdown]
# **Histograma**
# Mostra a distribuição de frequências de uma variável numérica dividida em “bins” (intervalos). Cada barra indica quantos valores caem em cada faixa. Use quando quiser entender a forma geral dos dados (simetria, sesgo, picôs múltiplos) e identificar aglomerados ou lacunas.

# %%
import matplotlib.pyplot as plt  

plt.hist(x)
plt.figure()
plt.show()

# %% [markdown]
# **Série temporal (line plot)**
# Plota um valor ao longo de um eixo temporal conectado por linhas. Ideal para acompanhar tendências, ciclos sazonais e rupturas em séries de tempo (ex.: evolução do ticket médio de Pix trimestre a trimestre). Ajuda a visualizar crescimento, quedas e padrões periódicos.

# %%
plt.plot(df['datatrimestre'],x, marker='o')
plt.grid()
plt.show()

# %% [markdown]
# **Box-plot**
# Representa a mediana, quartis e potenciais outliers de um conjunto de observações. A “caixa” vai do primeiro ao terceiro quartil, com uma linha na mediana, e “bigodes” indicando o alcance dos dados sem outliers. Use para comparar dispersão e simetria entre grupos (por exemplo, diferentes canais de pagamento) e para detectar valores atípicos.

# %%
plt.boxplot(x.dropna())
plt.show()

# %% [markdown]
# **Exercício:** Fazer um estudo das médias semelhante para os diferentes tipos de Cartões.

# %%
df.to_csv('transacaoCartao.csv', sep=';',decimal=',') # Padrão para dizer ao power BI o formato que tem nos numeros

# %% [markdown]
# Selecionando a variável  quantidadeBoleto e quantidadeDebitoDireto Para analisar e comparar

# %%
# Selecionando quantidadeBoleto para analisar (estatísticas básicas: quantidade, média, desvio padrão, mínimos, máximos e quartis)
boleto = df['quantidadeBoleto']  
print(boleto.describe())
# Out:
# count    2.400000e+01
# mean     1.389849e+08
# std      1.531292e+07
# min      1.020584e+08
# 25%      1.353764e+08
# 50%      1.455822e+08
# 75%      1.493783e+08
# max      1.538367e+08
# Name: quantidadeBoleto, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(boleto.dropna(), bins=20) 
plt.title('Distribuição da Quantidade de Boletos')  
plt.xlabel('Quantidade de Boletos')  # Eixo X: valores da variável
plt.ylabel('Frequência')  # Eixo Y: quantidade de ocorrências em cada intervalo

plt.show()  

# Comentário:
# O histograma serve para visualizar como os dados estão distribuídos.
# Ele ajuda a identificar concentração de valores, presença de outliers ( valores muito diferentes da maioria dos dados, podem ser extremos ou erros), assimetrias ou múltiplos picos.
# Essa análise visual é importante para entender o comportamento da variável antes de análises mais complexas.

# %%
print("Média:", boleto.mean())  
print("Variância:", boleto.var(ddof=0))  
print("Desvio-padrão:", boleto.std(ddof=0))  

# Calcula e mostra as principais estatísticas descritivas da variável 'quantidadeBoleto':
# - Média: valor médio dos dados
# - Variância: medida de dispersão em relação à média
# - Desvio-padrão: dispersão na mesma unidade dos dados
# Essas medidas ajudam a entender o comportamento e a variedaed dos dados para análises futuras.
# Out:
# Média: 138984854.16666666
# Variância: 224715254867482.62
# Desvio-padrão: 14990505.490725875

# %%
plt.plot(df['datatrimestre'], boleto, marker='o')  
plt.title('Quantidade de Boletos por Trimestre')  
plt.xlabel('Data Trimestre') 
plt.ylabel('Quantidade de Boletos') 

plt.grid()  
plt.show()  

# Esse gráfico serve para analisar a tendência temporal da quantidade de boletos ao longo dos trimestres.
# Permite identificar padrões, ciclos, aumentos ou quedas em determinados períodos.
# É útil para detectar sazonalidade ou mudanças importantes na série temporal.

# %%
# Soma total de cada tipo
total_boleto = df['quantidadeBoleto'].sum()
total_debito = df['quantidadeDebitoDireto'].sum()

# Dados para o gráfico
tipos = ['Quantidade Boleto', 'Quantidade Débito Direto']
valores = [total_boleto, total_debito]
# Gráfico de barras simples
plt.bar(tipos, valores, color=['blue', 'green'])
plt.title('Comparação: Quantidade Total de Boletos vs Débitos Diretos')
plt.ylabel('Quantidade Total')
plt.show()

# %%
# Comparando médias 
media_valor_boleto = df['valorBoleto'].mean()
media_valor_debito = df['valorDebitoDireto'].mean()

print("Média valor boleto:", media_valor_boleto)
print("Média valor débito direto:", media_valor_debito)
# Out:
# Média valor boleto: 1991933290833.3333
# Média valor débito direto: 689468077083.3334

# %%
plt.scatter(df['quantidadeBoleto'], df['valorBoleto'])
plt.title('Quantidade x Valor de Boletos')
plt.xlabel('Quantidade de Boletos')
plt.ylabel('Valor de Boletos')
plt.show()

# %%
# Agrupa e soma por trimestre
soma_boleto = df.groupby('datatrimestre')['quantidadeBoleto'].sum()
soma_debito = df.groupby('datatrimestre')['quantidadeDebitoDireto'].sum()

# Cria um DataFrame só para facilitar a comparação
comparacao = pd.DataFrame({
    'Boletos': soma_boleto,
    'Débito Direto': soma_debito
})

# Gráfico de linha para comparar os dois ao longo do tempo
comparacao.plot(marker='o')
plt.title('Quantidade de Boletos vs Débitos Diretos por Trimestre')
plt.xlabel('Trimestre')
plt.ylabel('Quantidade Total')
plt.grid()
plt.show()

# Mostrar qual foi maior em cada trimestre (opcional)
comparacao['Maior'] = comparacao.idxmax(axis=1)
print(comparacao)
# Out:
#                    Boletos  Débito Direto          Maior
# datatrimestre
# 2019-03-31     102058400.0    138146700.0  Débito Direto
# 2019-06-30     107681300.0    141874900.0  Débito Direto
# 2019-09-30     115511300.0    151440500.0  Débito Direto
# 2019-12-31     119039800.0    145919400.0  Débito Direto
# 2020-03-31     118451100.0    152264500.0  Débito Direto
# 2020-06-30     125681200.0    154258100.0  Débito Direto
# 2020-09-30     138921600.0    162325200.0  Débito Direto
# 2020-12-31     147286900.0    170053200.0  Débito Direto
# 2021-03-31     138608100.0    170425400.0  Débito Direto
# 2021-06-30     143142700.0    170901000.0  Débito Direto
# 2021-09-30     149363800.0    176546500.0  Débito Direto
# 2021-12-31     149770500.0    180999200.0  Débito Direto
# 2022-03-31     149093400.0    204956700.0  Débito Direto
# 2022-06-30     151709300.0    201760900.0  Débito Direto
# 2022-09-30     153836700.0    196530800.0  Débito Direto
# 2022-12-31     152248400.0    193534800.0  Débito Direto
# 2023-03-31     151081800.0    243725400.0  Débito Direto
# 2023-06-30     149421800.0    255623700.0  Débito Direto
# 2023-09-30     148707300.0    279082000.0  Débito Direto
# 2023-12-31     145247900.0    310255800.0  Débito Direto
# 2024-03-31     142273100.0    323869900.0  Débito Direto
# 2024-06-30     143910000.0    332059000.0  Débito Direto
# 2024-09-30     146673700.0    383257700.0  Débito Direto
# 2024-12-31     145916400.0    379510300.0  Débito Direto
